# %% [markdown]
# # Weighted Pull up & Front Lever Survey

# %% [markdown]
# ## Data cleaning

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
import re
from statistics import mean

# %%
raw = pd.read_csv("Front Lever and Pullups correlation (Responses) - Form Responses 1(1).csv",encoding = "ISO-8859-1")

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 7 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   Timestamp                                          609 non-null    object
#  1   Weighted Pullup 1RM (% of BW)                      609 non-null    object
#  2   Max Front Lever progression (3 seconds good form)  609 non-null    object
#  3   Other thoughts or comments? Helpful data           219 non-null    object
#  4   Bodyweight (kg)                                    595 non-null    object
#  5   Max pullups (endurance)                            587 non-null    object
#  6   Height (cm)                                        498 non-null    object
# dtypes: object(7)
# memory usage: 33.5+ KB

# %%
copy = raw.copy()

# %%
copy.dropna(axis=0,how='all').reset_index()
# Out:
#      index         Timestamp                Weighted Pullup 1RM (% of BW)  \
# 0        0    10/7/2020 0:41  <10% (so usually couple of pullups with BW)
# 1        1   10/6/2020 20:38                                      65%-80%
# 2        2    10/7/2020 1:41                                      50%-65%
# 3        3   10/6/2020 19:50                                      50%-65%
# 4        4   10/6/2020 20:10                                      30%-50%
# ..     ...               ...                                          ...
# 604    606  12/20/2020 21:37                                         >90%
# 605    607  12/20/2020 21:38                                      65%-80%
# 606    608  12/20/2020 22:44                                      10%-30%
# 607    609  12/20/2020 22:55                                      65%-80%
# 608    610  12/20/2020 23:51                                      50%-65%
#
#     Max Front Lever progression (3 seconds good form)  \
# 0                                      Straddle lever
# 1                                          Full lever
# 2                              Straddle Halflay lever
# 3                                      Straddle lever
# 4                                          Full lever
# ..                                                ...
# 604                                        Full lever
# 605                                        Full lever
# 606                                        Tuck lever
# 607                                    Straddle lever
# 608                               Advanced Tuck lever
#
#               Other thoughts or comments? Helpful data Bodyweight (kg)  \
# 0                                                  NaN            59.8
# 1                                                  NaN              72
# 2    I have 50% weighted pull up and barely 3 secon...              68
# 3                                                  NaN              62
# 4                                                  NaN              45
# ..                                                 ...             ...
# 604  It may be related to both weighted pull ups an...              55
# 605                                                NaN              72
# 606                                                NaN              88
# 607                                               none              65
# 608  I feel height makes a difference in one's abil...              68
#
#     Max pullups (endurance) Height (cm)
# 0                        20        1.65
# 1                        21        1.78
# 2                        17          69
# 3                        20         142
# 4                        20         160
# ..                      ...         ...
# 604                      27         170
# 605                      22         175
# 606                      10         187
# 607                      35         170
# 608                      15         183
#
# [609 rows x 8 columns]

# %%
weight = []
for i in copy.index:
    bw = copy["Bodyweight (kg)"][i]
    bw_extracted = re.findall('(\d+(.\d+)?)',str(bw))
    try:
        if re.match('(\d{2}-\d{2})',bw_extracted[0][0]) is not None:
            weight_range = [int(x) for x in bw_extracted[0][0].split("-")]
            weight.append(mean(weight_range))
        else:
            weight.append(float(bw_extracted[0][0]))
    except:
        weight.append('')

# %%
copy["Bodyweight (kg)"] = weight

# %%
height = []
for i in copy.index:
    he = copy["Height (cm)"][i]
    he_extracted = re.findall('(\d+(.\d+)?)',str(he))
    try:
        he_cleaned = he_extracted[0][0].replace(',','.').replace('cm','').replace('m','')
        if re.match('\d.\d{2}',he_cleaned) is not None:
            height.append(float(he_cleaned)*100)
        else:
            height.append(float(he_cleaned))
    except:
        height.append('')

# %%
copy["Height (cm)"] = height

# %%
copy["Height (cm)"][2] = 169.0

# %%
maxpulls = []
for i in copy.index:
    mpulls = copy["Max pullups (endurance)"][i]
    mp_extracted = [int(x) for x in re.findall('\d+',str(mpulls))]
    if len(mp_extracted) >= 1:
        maxpulls.append(mean(mp_extracted))
    else:
        maxpulls.append('')

# %%
copy["Max pullups (endurance)"] = maxpulls

# %%
copy.dropna(axis=0,how='all')
# Out:
#             Timestamp                Weighted Pullup 1RM (% of BW)  \
# 0      10/7/2020 0:41  <10% (so usually couple of pullups with BW)
# 1     10/6/2020 20:38                                      65%-80%
# 2      10/7/2020 1:41                                      50%-65%
# 3     10/6/2020 19:50                                      50%-65%
# 4     10/6/2020 20:10                                      30%-50%
# ..                ...                                          ...
# 606  12/20/2020 21:37                                         >90%
# 607  12/20/2020 21:38                                      65%-80%
# 608  12/20/2020 22:44                                      10%-30%
# 609  12/20/2020 22:55                                      65%-80%
# 610  12/20/2020 23:51                                      50%-65%
#
#     Max Front Lever progression (3 seconds good form)  \
# 0                                      Straddle lever
# 1                                          Full lever
# 2                              Straddle Halflay lever
# 3                                      Straddle lever
# 4                                          Full lever
# ..                                                ...
# 606                                        Full lever
# 607                                        Full lever
# 608                                        Tuck lever
# 609                                    Straddle lever
# 610                               Advanced Tuck lever
#
#               Other thoughts or comments? Helpful data Bodyweight (kg)  \
# 0                                                  NaN            59.8
# 1                                                  NaN              72
# 2    I have 50% weighted pull up and barely 3 secon...              68
# 3                                                  NaN              62
# 4                                                  NaN              45
# ..                                                 ...             ...
# 606  It may be related to both weighted pull ups an...              55
# 607                                                NaN              72
# 608                                                NaN              88
# 609                                               none              65
# 610  I feel height makes a difference in one's abil...              68
#
#     Max pullups (endurance) Height (cm)
# 0                        20         165
# 1                        21         178
# 2                        17         169
# 3                        20         142
# 4                        20         160
# ..                      ...         ...
# 606                      27         170
# 607                      22         175
# 608                      10         187
# 609                      35         170
# 610                      15         183
#
# [611 rows x 7 columns]

# %%
copy.dropna(axis=0,how='all').reset_index()
# Out:
#      index         Timestamp                Weighted Pullup 1RM (% of BW)  \
# 0        0    10/7/2020 0:41  <10% (so usually couple of pullups with BW)
# 1        1   10/6/2020 20:38                                      65%-80%
# 2        2    10/7/2020 1:41                                      50%-65%
# 3        3   10/6/2020 19:50                                      50%-65%
# 4        4   10/6/2020 20:10                                      30%-50%
# ..     ...               ...                                          ...
# 606    606  12/20/2020 21:37                                         >90%
# 607    607  12/20/2020 21:38                                      65%-80%
# 608    608  12/20/2020 22:44                                      10%-30%
# 609    609  12/20/2020 22:55                                      65%-80%
# 610    610  12/20/2020 23:51                                      50%-65%
#
#     Max Front Lever progression (3 seconds good form)  \
# 0                                      Straddle lever
# 1                                          Full lever
# 2                              Straddle Halflay lever
# 3                                      Straddle lever
# 4                                          Full lever
# ..                                                ...
# 606                                        Full lever
# 607                                        Full lever
# 608                                        Tuck lever
# 609                                    Straddle lever
# 610                               Advanced Tuck lever
#
#               Other thoughts or comments? Helpful data Bodyweight (kg)  \
# 0                                                  NaN            59.8
# 1                                                  NaN              72
# 2    I have 50% weighted pull up and barely 3 secon...              68
# 3                                                  NaN              62
# 4                                                  NaN              45
# ..                                                 ...             ...
# 606  It may be related to both weighted pull ups an...              55
# 607                                                NaN              72
# 608                                                NaN              88
# 609                                               none              65
# 610  I feel height makes a difference in one's abil...              68
#
#     Max pullups (endurance) Height (cm)
# 0                        20         165
# 1                        21         178
# 2                        17         169
# 3                        20         142
# 4                        20         160
# ..                      ...         ...
# 606                      27         170
# 607                      22         175
# 608                      10         187
# 609                      35         170
# 610                      15         183
#
# [611 rows x 8 columns]

# %%
copy.to_csv("Weight PU and FL cleaned.csv",index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-1e776dc76462> in <module>
# ----> 1 copy.to_csv("Weight PU and FL cleaned.csv",index=False)
#
# NameError: name 'copy' is not defined

# %%
cleaned = pd.read_csv("Weighted PU and FL cleaned.csv",encoding = "ISO-8859-1")

# %%
cleaned.columns
# Out:
# Index(['Timestamp', 'Weighted Pullup 1RM (% of BW)',
#        'Max Front Lever progression (3 seconds good form)',
#        'Other thoughts or comments? Helpful data', 'Bodyweight (kg)',
#        'Max pullups (endurance)', 'Height (cm)'],
#       dtype='object')

# %%
cleaned['Weighted Pullup 1RM (% of BW)'] = cleaned['Weighted Pullup 1RM (% of BW)'].apply(lambda x : x.replace("<10% (so usually couple of pullups with BW)","<10%"))

# %%
cleaned.head()
# Out:
#          Timestamp Weighted Pullup 1RM (% of BW)  \
# 0   10/7/2020 0:41                          <10%
# 1  10/6/2020 20:38                       65%-80%
# 2   10/7/2020 1:41                       50%-65%
# 3  10/6/2020 19:50                       50%-65%
# 4  10/6/2020 20:10                       30%-50%
#
#   Max Front Lever progression (3 seconds good form)  \
# 0                                    Straddle lever
# 1                                        Full lever
# 2                            Straddle Halflay lever
# 3                                    Straddle lever
# 4                                        Full lever
#
#             Other thoughts or comments? Helpful data  Bodyweight (kg)  \
# 0                                                NaN             59.8
# 1                                                NaN             72.0
# 2  I have 50% weighted pull up and barely 3 secon...             68.0
# 3                                                NaN             62.0
# 4                                                NaN             45.0
#
#    Max pullups (endurance)  Height (cm)
# 0                     20.0        165.0
# 1                     21.0        178.0
# 2                     17.0        169.0
# 3                     20.0        142.0
# 4                     20.0        160.0

# %%
cleaned.to_csv("Weighted PU and FL cleaned.csv",index=False)
